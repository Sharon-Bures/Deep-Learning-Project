# %%
import pandas as pd

# %%
train_bodies = pd.read_csv('train_bodies.csv')
train_stances = pd.read_csv('train_stances.csv')

# %%
train_bodies
# Out:
#       Body ID                                        articleBody
# 0           0  A small meteorite crashed into a wooded area i...
# 1           4  Last week we hinted at what was to come as Ebo...
# 2           5  (NEWSER) – Wonder how long a Quarter Pounder w...
# 3           6  Posting photos of a gun-toting child online, I...
# 4           7  At least 25 suspected Boko Haram insurgents we...
# ...       ...                                                ...
# 1678     2528  Intelligence agencies hunting for identity of ...
# 1679     2529  While Daleks "know no fear" and "must not fear...
# 1680     2530  More than 200 schoolgirls were kidnapped in Ap...
# 1681     2531  A Guantanamo Bay prisoner released last year a...
# 1682     2532  ANN ARBOR, Mich. – A pizza delivery man in Mic...
#
# [1683 rows x 2 columns]

# %%
trial_bodies=train_bodies[train_bodies['Body ID']==712].values
trial_stances=train_stances[train_stances['Body ID']==712].values
print(trial_bodies, trial_stances)
# Out:
# [[712
#   'Danny Boyle is directing the untitled film\n\nSeth Rogen is being eyed to play Apple co-founder Steve Wozniak in Sony’s Steve Jobs biopic.\n\nDanny Boyle is directing the untitled film, based on Walter Isaacson\'s book and adapted by Aaron Sorkin, which is one of the most anticipated biopics in recent years.\n\nNegotiations have not yet begun, and it’s not even clear if Rogen has an official offer, but the producers — Scott Rudin, Guymon Casady and Mark Gordon — have set their sights on the talent and are in talks.\n\nOf course, this may all be for naught as Christian Bale, the actor who is to play Jobs, is still in the midst of closing his deal. Sources say that dealmaking process is in a sensitive stage.\n\nInsiders say Boyle will is flying to Los Angeles to meet with actress to play one of the female leads, an assistant to Jobs. Insiders say that Jessica Chastain is one of the actresses on the meeting list.\n\nWozniak, known as "Woz," co-founded Apple with Jobs and Ronald Wayne. He first met Jobs when they worked at Atari and later was responsible for creating the early Apple computers.']] [["Police find mass graves with at least '15 bodies' near Mexico town where 43 students disappeared after police clash"
#   712 'unrelated']
#  ['Seth Rogen to Play Apple’s Steve Wozniak' 712 'discuss']
#  ['Mexico police find mass grave near site 43 students vanished' 712
#   'unrelated']
#  ['Mexico Says Missing Students Not Found In First Mass Graves' 712
#   'unrelated']
#  ['New iOS 8 bug can delete all of your iCloud documents' 712 'unrelated']
#  ['Return of the Mac: Seth Rogen in talks to star as Apple co-founder Steve Wozniak in upcoming Steve Jobs biopic'
#   712 'discuss']
#  ['Seth Rogen Is Woz' 712 'discuss']
#  ['Mexico finds 4 more graves at site of suspected student massacre' 712
#   'unrelated']
#  ['Are missing students in mass graves found near Iguala, Mexico?' 712
#   'unrelated']
#  ['Mexico prosecutor: Students not in 1st mass graves' 712 'unrelated']
#  ["Lady on FB: I'm 41, Intersex, and Fucked Michael Phelps on First Date"
#   712 'unrelated']
#  ['Catholic Priest Claims God Is Female After Clinically Dead Experience'
#   712 'unrelated']
#  ['Isis claims US hostage Kayla Mueller killed in coalition airstrike'
#   712 'unrelated']
#  ['Gold Apple Watch Edition price? Speculators say at least $10,000' 712
#   'unrelated']
#  ['Mexican students not among bodies found in mass graves' 712
#   'unrelated']
#  ['Steve Jobs Biopic Eyes Seth Rogen to Play Apple Co-Founder Steve Wozniak'
#   712 'discuss']
#  ['Missing Mexico students not among 28 bodies found in mass grave' 712
#   'unrelated']
#  ['Taylor Lianne Chandler: Everything you need to know about Michael Phelps’ intersex girlfriend'
#   712 'unrelated']
#  ['Mexican cartel leader kills self; bodies in grave not missing students'
#   712 'unrelated']
#  ['Bodies In Mexico Mass Grave Apparently Not Those Of Missing Students'
#   712 'unrelated']
#  ["Seth Rogen Eyed to Play Apple's Steve Wozniak in Christian Bale's Steve Jobs Movie (Exclusive)"
#   712 'discuss']
#  ['Mexican investigators fear mass grave might hold 43 missing students'
#   712 'unrelated']
#  ['6 hidden mass graves may hold missing Mexican students' 712
#   'unrelated']
#  ['Mass grave found after 40 students disappear in Mexican protest' 712
#   'unrelated']
#  ['Mexico Student Massacre Update: More Graves Discovered At Murder Site'
#   712 'unrelated']
#  ['Seth Rogen To Play Steve Wozniak In Steve Jobs Biopic' 712 'discuss']
#  ["Taylor Lianne Chandler: Michael Phelps' Cougar Girlfriend Revealed?"
#   712 'unrelated']
#  ['Newly Discovered Mass Grave Linked to Missing Mexican Students' 712
#   'unrelated']
#  ["Michael Phelps' self-proclaimed 'girlfriend', 41, reveals she was born a male as she describes her 'amazing intimacy' with Olympic swimmer"
#   712 'unrelated']
#  ["Missing Mexican students 'not found in mass grave'" 712 'unrelated']
#  ['Mexico checks if 43 missing students in mass grave' 712 'unrelated']
#  ["Rumor: Seth Rogen to Appear as Woz in Sony's Steve Jobs Film" 712
#   'discuss']
#  ['This Powerful Cartoon About The Charlie Hebdo Attack Is Not By Banksy'
#   712 'unrelated']
#  ['Mexico Says Students Not Among Dead in Mass Grave' 712 'unrelated']
#  ["Mexico hit by student massacre: At least 17 anti-corruption protesters 'rounded up, murdered and dumped in a mass grave' - and another 26 are missing"
#   712 'unrelated']
#  ["Seth Rogen to Star as Steve Wozniak in Sony's Steve Jobs Biopic [Updated]"
#   712 'discuss']
#  ['Michael Phelps’ alleged girlfriend says she was born intersex' 712
#   'unrelated']
#  ['Mass Graves Found In Mexico, Near Place Where 43 Students Went Missing'
#   712 'unrelated']
#  ['A Mass Grave Points to a Student Massacre in Mexico' 712 'unrelated']]

# %%
train_stances
# Out:
#                                                 Headline  Body ID     Stance
# 0      Police find mass graves with at least '15 bodi...      712  unrelated
# 1      Hundreds of Palestinians flee floods in Gaza a...      158      agree
# 2      Christian Bale passes on role of Steve Jobs, a...      137  unrelated
# 3      HBO and Apple in Talks for $15/Month Apple TV ...     1034  unrelated
# 4      Spider burrowed through tourist's stomach and ...     1923   disagree
# ...                                                  ...      ...        ...
# 49967  Urgent: The Leader of ISIL 'Abu Bakr al-Baghda...     1681  unrelated
# 49968  Brian Williams slams social media for speculat...     2419  unrelated
# 49969  Mexico Says Missing Students Not Found In Firs...     1156      agree
# 49970  US Lawmaker: Ten ISIS Fighters Have Been Appre...     1012    discuss
# 49971  Shots Heard In Alleged Brown Shooting Recordin...     2044  unrelated
#
# [49972 rows x 3 columns]
